# %%
import tweepy,sys,jsonpickle

consumer_key = 'ld6T6DU30oDMobmCfQgGpo7qU'
consumer_secret = 'umXgXTQzZxQ5UobTVyLgcmzNT5GYSegrrCMQ9K5JmMGCHs6Bgl'

access_token = '1096278117700628480-rAnVro8q3GQ4kffBqKig9nbrJy2rvll'
access_token_secret = 'jvnviCo3lBrVwf1yAgWjgpRBRNUNoOFhzQe89iIoh93ok'

qry='#TragediKemanusiaanKM50'
maxTweets = 2000 #barang nilai sesuai kebutuhan anda
tweetsPerQry = 100  # Jangan isi lebih dari 100, ndak boleh oleh Twitter
fName='E:\\Repaldi Handi S\\1. Crawling Data\\TragediKemanusiaanKM50.json'

auth = tweepy.AppAuthHandler(consumer_key,consumer_secret)
api = tweepy.API(auth, wait_on_rate_limit=True,wait_on_rate_limit_notify=True)

if (not api):
    sys.exit('Autentikasi gagal, mohon cek "Consumer Key" & "Consumer Secret" Twitter anda')

sinceId, max_id, tweetCount = None, -1, 0

print("Mulai mengunduh maksimum {0} tweets".format(maxTweets))
with open(fName,'w') as f:
    while tweetCount < maxTweets:
        try:
            if (max_id <= 0):
                if (not sinceId):
                    new_tweets=api.search(q=qry,count=tweetsPerQry)
                else:
                    new_tweets=api.search(q=qry,count=tweetsPerQry,since_id=sinceId)
            else:
                if (not sinceId):
                    new_tweets=api.search(q=qry,count=tweetsPerQry,max_id=str(max_id - 1))
                else:
                    new_tweets=api.search(q=qry,count=tweetsPerQry,max_id=str(max_id - 1),since_id=sinceId)
            if not new_tweets:
                print('Tidak ada lagi Tweet ditemukan dengan Query="{0}"'.format(qry));break
            for tweet in new_tweets:
                f.write(jsonpickle.encode(tweet._json,unpicklable=False)+'\n')
            tweetCount+=len(new_tweets)
            sys.stdout.write("\r");sys.stdout.write("Jumlah Tweets telah tersimpan: %.0f" %tweetCount);sys.stdout.flush()
            max_id=new_tweets[-1].id
        except tweepy.TweepError as e:
            print("some error : " + str(e));break # Aya error, keluar
print ('\nSelesai! {0} tweets tersimpan di "{1}"'.format(tweetCount,fName))
# Out:
# Mulai mengunduh maksimum 2000 tweets
# Jumlah Tweets telah tersimpan: 2000
# Selesai! 2000 tweets tersimpan di "E:\Repaldi Handi S\1. Crawling Data\TragediKemanusiaanKM50.json"

# %%
import json

tweets = []

for line in open('E:\\Repaldi Handi S\\1. Crawling Data\\TragediKemanusiaanKM50.json'):
        try:
            tweets.append(json.loads(line))
        except:
            continue
#print (len(tweets)) #untuk mengetahui jumlah tweet
for tweet in tweets:
            try:
                
                print (tweet['text']) #masukin variable yg mau di ambil
                file = open('E:\\Repaldi Handi S\\2. Parsing Json to txt\\parse.txt', 'a') 
                file.write(tweet['text']) 
                file.close() 
            except:
                pass
# Out:
# RT @BiruniSaja: Yang RT(retweet) saya follback 😊
# #TragediKemanusiaanKM50
# @RestyCayaah Ohhhhhhhhhhhhhhhhhhhh
# Ohhhhhhhhhhhhhhhhhhh
# Ohhhhhhhhhhhhhhhhhh
# Ohhhhhhhhhhhhhhhhh
# Ohhhhhhhhhhhhhhhh
# Oh… https://t.co/OyiTsJsxMK
# Tetep disini,,,
#
# #TragediKemanusiaanKM50
# #TragediKemanusiaanKM50 https://t.co/cJFIWWkBLE
# @Raj4Purwa Segera..
# #TangkapAnakPakLurah
#
# Dan Usut Tuntas..
# #TragediKemanusiaanKM50
# krg lebih spt inilah
# #TragediKemanusiaanKM50
# #TragediKemanusiaanKM50 https://t.co/QwCTHDXccA
# RT @Namaku_Anisa: Yang RT(retweet) saya follback
# #TragediKemanusiaanKM50
# RT @BiruniSaja: Yang RT(retweet) saya follback 😊
# #TragediKemanusiaanKM50
# RT @BebekMilenial: Up nyok....!!!
#
# Yang RT gue follow  !!!
#
# 😍😍😍😍😍😍
#
#  #TragediKemanusiaanKM50  #TangkapAnakPakLurah https://t.co/YYBMLN5uGM
# RT @Raj4Purwa: Alur Ceritanya...
# #TangkapAnakPakLurah
# #TragediKemanusiaanKM50 https://t.co/zEXqBsLSB7
# RT @bubey54: Coba kalian pakai otak yaa...
#
# ...

# %%
import string
remove = dict.fromkeys(map(ord, '\n' + string.punctuation))
with open ('E:\\Repaldi Handi S\\2. Parsing Json to txt\\parse.txt') as inputfile:
  f = inputfile.read().translate(remove)

file = open('E:\\Repaldi Handi S\\3. Cleaning\\cleaningText.txt', 'a') 
file.write(f) 
file.close() 
print (f)
# Out:
# 85albasrihasan ninggalin jejak  TragediKemanusiaanKM50RestyCayaah OhhhhhhhhhhhhhhhhhhhhOhhhhhhhhhhhhhhhhhhhOhhhhhhhhhhhhhhhhhhOhhhhhhhhhhhhhhhhhOhhhhhhhhhhhhhhhhOh… httpstcoOyiTsJsxMKTetep disini TragediKemanusiaanKM50TragediKemanusiaanKM50 httpstcocJFIWWkBLERaj4Purwa Segera TangkapAnakPakLurah Dan Usut Tuntas TragediKemanusiaanKM50krg lebih spt inilah TragediKemanusiaanKM50 TragediKemanusiaanKM50 httpstcoQwCTHDXccART NamakuAnisa Yang RTretweet saya follbackTragediKemanusiaanKM50RT Raj4Purwa Alur CeritanyaTangkapAnakPakLurahTragediKemanusiaanKM50 httpstcozEXqBsLSB7RT bubey54 Coba kalian pakai otak yaaAnggota ormas melakukan kesalahan yang jelas² tidak berdampak pada masyarakat luas kok ormasnya…RT CasperBeWin1 Dilansir Chanel OPPOSITE 6890Kondisi Jenazah 6 Korban PENEMBAKAN DI KM50Dan juga Telisik temponewsroomhttpstcof…RT DarkOfSpartan ThreadHi sobat tweeps semuanya kembali lagi hadir bersama DLJ Untuk dimalam hari ini ingin membagikan kumpulan beri…RT NamakuAnisa Yang RTretweet say
# ...

# %%
import nltk #natural languange toolkit, platform yg digunakan utk membangun program utk analisis teks
nltk.download('punkt')
file_content = open('E:\\Repaldi Handi S\\3. Cleaning\\cleaningText.txt').read()
tokens = nltk.word_tokenize(file_content)
print (tokens)
file = open('E:\\Repaldi Handi S\\4. Tokenisasi\\tokenisasiText.txt', 'a') 
file.write(str(tokens))
file.close()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %%
import Sastrawi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
file_content = open("E:\\Repaldi Handi S\\4. Tokenisasi\\tokenisasiText.txt").read()

factory = StemmerFactory()
stemmer = factory.create_stemmer()
sudahstem = stemmer.stem(file_content)
file = open('E:\\Repaldi Handi S\\5. Skeaming\\skeamingText.txt', 'a') 
file.write(sudahstem) 
file.close() 

print(sudahstem)
# Out:
# 85albasrihasan ninggalin jejak tragedikemanusiaankm50restycayaah ohhhhhhhhhhhhhhhhhhhhohhhhhhhhhhhhhhhhhhhohhhhhhhhhhhhhhhhhhohhhhhhhhhhhhhhhhhohhhhhhhhhhhhhhhhoh httpstcooyitsjsxmktetep sini tragedikemanusiaankm50tragedikemanusiaankm50 httpstcocjfiwwkbleraj4purwa segera tangkapanakpaklurah dan usut tuntas tragedikemanusiaankm50krg lebih spt ini tragedikemanusiaankm50 tragedikemanusiaankm50 httpstcoqwcthdxccart namakuanisa yang rtretweet saya follbacktragedikemanusiaankm50rt raj4purwa alur ceritanyatangkapanakpaklurahtragedikemanusiaankm50 httpstcozexqbslsb7rt bubey54 coba kalian pakai otak yaaanggota ormas laku salah yang jelas tidak dampak pada masyarakat luas kok ormasnya rt casperbewin1 lansir chanel opposite 6890kondisi jenazah 6 korban tembak di km50dan juga tisik temponewsroomhttpstcof rt darkofspartan threadhi sobat tweeps semua kembali lagi hadir sama dlj untuk malam hari ini ingin bagi kumpul beri rt namakuanisa yang rtretweet saya follbacktragedikemanusiaankm50tragedikeman
# ...

# %%
import Sastrawi
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
file_content = open('E:\\Repaldi Handi S\\5. Skeaming\\skeamingText.txt').read()
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()
kalimat = file_content
stop = stopword.remove(kalimat)
file = open('E:\\Repaldi Handi S\\5. Skeaming\\skeamingText_Final.txt', 'a') 
file.write(stop) 
file.close() 
print(stop)
# Out:
# 85albasrihasan ninggalin jejak tragedikemanusiaankm50restycayaah ohhhhhhhhhhhhhhhhhhhhohhhhhhhhhhhhhhhhhhhohhhhhhhhhhhhhhhhhhohhhhhhhhhhhhhhhhhohhhhhhhhhhhhhhhhoh httpstcooyitsjsxmktetep sini tragedikemanusiaankm50tragedikemanusiaankm50 httpstcocjfiwwkbleraj4purwa segera tangkapanakpaklurah usut tuntas tragedikemanusiaankm50krg lebih spt tragedikemanusiaankm50 tragedikemanusiaankm50 httpstcoqwcthdxccart namakuanisa rtretweet follbacktragedikemanusiaankm50rt raj4purwa alur ceritanyatangkapanakpaklurahtragedikemanusiaankm50 httpstcozexqbslsb7rt bubey54 coba kalian pakai otak yaaanggota ormas laku salah jelas dampak masyarakat luas kok ormasnya rt casperbewin1 lansir chanel opposite 6890kondisi jenazah 6 korban tembak km50dan tisik temponewsroomhttpstcof rt darkofspartan threadhi sobat tweeps semua hadir sama dlj malam hari kumpul beri rt namakuanisa rtretweet follbacktragedikemanusiaankm50tragedikemanusiaankm50 tragedikemanusiaankm50 httpstcoxi0gvpte5xputrawadapi setiadiyudizaza tangka
# ...

# %%
import pandas as pd
raw_data = open(r"E:\\Repaldi Handi S\\5. Skeaming\\skeamingText_Final.txt")
for line in raw_data:
    unique_line_list = set(line.split())d
    pd.Series(list(unique_line_list)).to_csv(r'E:\\Repaldi Handi S\\5. Skeaming\\data-update.csv', index = False)
    print(unique_line_list)
# Out:
# {'3660', 'tragedikemanusiaankm50the', 'adaudppnp', 'juga', 'syuhada', 'rojiun', 'httpstcoqcyvs9knaytangkapanakpaklurah', 'revenger1924', 'tangkep2an', 'geram', 'setanalaska', 'httpstcosciyeqbu14lelaki5unyi', 'mohishaq17', 'lbh', 'telor', 'defenders', 'tupoksi', 'curang', 'cerita', 'httpstcoqkyhlfsnfort', 'pantat', 'logo', 'marlinaidha', 'mw', 'kan', 'di', 'cahangonori', 'ahhtragedikemanusiaankm50semoga', 'sukses', 'pager', 'httpstcoxynygg5n0bcek', 'httpstco7cevwox1o3queenb4ck', 'ohohtragedikemanusiaankm50hohotangkapanakpaklurah', 'tanga', 'httpstcomprup1u0ahrt', 'mueeza02', 'budiyonofattah', 'akan', 'merana', 'refund', 'dimanamana', 'httpstcof7huvcavh5rt', 'tragedikemanusiaankm50savemoslem1', 'httpstcounhu13nntebebekmilenial', 'munafik', 'jaga', 'httpstcoex1ywcs0mzrt', 'nove', 'kardun2', 'httpstcovexwk2tzweohhhhhhhhhhhhhhhhhhohhhhhhhhhhhhhhhhhohhhhhhhhhhhhhhhhohhhhhhhhhhhhhhhohhhhhhhhhhhhhhohhhhhhhhhhhhhohhhhhhhhh', 'gimana', 'silah', 'iya', 'cr', 'tragedikemanusiaankm50tr', 'keras',
# ...

# %%
import sys, math, re
from operator import itemgetter
import math


#buka file nya
wF = open('E:\\Repaldi Handi S\\5. Skeaming\\data-update.csv', 'r')

wordFile = wF.read()
wordList = wordFile.upper()
wordList = wordFile.split()

#buka wordlist, bikin wordlist = copy file yg di buka
kWF = open('E:\\Repaldi Handi S\\5. Skeaming\\wordlist.csv', 'r')

keywordFile = kWF.read()
KeywordList = keywordFile.upper()
keywordList = keywordFile.split()

word = 'k'
document = 'wordlist'
wordlist = 'w'

#total term di file
def countTerm(word, document):
        return
for k in keywordList:
    countTerm = 0
    for w in wordList:
        if k == w:
            countTerm = countTerm + 1
        if k == "TERM ini ":
           print (k, w, countTerm)
    print ('kata : ',k, 'sebanyak ', countTerm)

    print ('______________________________________________________________________')



print ('[]][][][][][][][][][][][][][][][][][][][][]][][][][[]][][][][][][][][][][][][][][][][][[][][][]][][][]][][]][]][][][[]]')

print ('[]][][][][][][][][][][][][][][][][][][][][]][][][][[]][][][][][][][][][][][][][][][][][[][][][]][][][]][][]][]][][][[]]')
print ('[]][][][][][][][][][][][][][][][][][][][][]][][][][[]][][][][][][][][][][][][][][][][][[][][][]][][][]][][]][]][][][[]]')
print ('[]][][][][][][][][][][][][][][][][][][][][]][][][][[]][][][][][][][][][][][][][][][][][[][][][]][][][]][][]][]][][][[]]')
print ('[]][][][][][][][][][][][][][][][][][][][][]][][][][[]][][][][][][][][][][][][][][][][][[][][][]][][][]][][]][]][][][[]]')
print ('[]][][][][][][][][][][][][][][][][][][][][]][][][][[]][][][][][][][][][][][][][][][][][[][][][]][][][]][][]][]][][][[]]')
print ('[]][][][][][][][][][][][][][][][][][][][][]][][][][[]][][][][][][][][][][][][][][][][][[][][][]][][][]][][]][]][][][[]]')
#total kata di dokumen
def wordfreq(wordList):
    return
wordfreq = [wordList.count(p) for p in wordList]
dictionary = dict(zip(wordList, wordfreq))
count2 = 0
for t in wordList:
    count2+=1
print ('total kata : ', count2)


print ('[]][][][][][][][][][][][][][][][][][][][][]][][][][[]][][][][][][][][][][][][][][][][][[][][][]][][][]][][]][]][][][[]]')
print ('[]][][][][][][][][][][][][][][][][][][][][]][][][][[]][][][][][][][][][][][][][][][][][[][][][]][][][]][][]][]][][][[]]')
print ('[]][][][][][][][][][][][][][][][][][][][][]][][][][[]][][][][][][][][][][][][][][][][][[][][][]][][][]][][]][]][][][[]]')
print ('[]][][][][][][][][][][][][][][][][][][][][]][][][][[]][][][][][][][][][][][][][][][][][[][][][]][][][]][][]][]][][][[]]')
print ('[]][][][][][][][][][][][][][][][][][][][][]][][][][[]][][][][][][][][][][][][][][][][][[][][][]][][][]][][]][]][][][[]]')


#total number of file being processed
def docfreq(k, wF):
    count = 0
    for wordList in wF:
        if countTerm(k, w) > 0:
            count += 1

    return count
print ("jumlah FILE yg di proses : ",countTerm)

print ('[]][][][][][][][][][][][][][][][][][][][][]][][][][[]][][][][][][][][][][][][][][][][][[][][][]][][][]][][]][]][][][[]]')
print ('[]][][][][][][][][][][][][][][][][][][][][]][][][][[]][][][][][][][][][][][][][][][][][[][][][]][][][]][][]][]][][][[]]')
print ('[]][][][][][][][][][][][][][][][][][][][][]][][][][[]][][][][][][][][][][][][][][][][][[][][][]][][][]][][]][]][][][[]]')
print ('[]][][][][][][][][][][][][][][][][][][][][]][][][][[]][][][][][][][][][][][][][][][][][[][][][]][][][]][][]][]][][][[]]')
print ('[]][][][][][][][][][][][][][][][][][][][][]][][][][[]][][][][][][][][][][][][][][][][][[][][][]][][][]][][]][]][][][[]]')
print ('[]][][][][][][][][][][][][][][][][][][][][]][][][][[]][][][][][][][][][][][][][][][][][[][][][]][][][]][][]][]][][][[]]')
print ('[]][][][][][][][][][][][][][][][][][][][][]][][][][[]][][][][][][][][][][][][][][][][][[][][][]][][][]][][]][]][][][[]]')


print ('-----------------------')
print ('-------PEMBOBOTAN :----------')
print ('-------PEMBOBOTAN :----------')
print ('-------PEMBOBOTAN :----------')
print ('-------PEMBOBOTAN :----------')
print ('-------PEMBOBOTAN :----------')
print ('-------PEMBOBOTAN :----------')

print ('\/\/\/\/\//\/\/\///\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\\/\/\/')
print ('\/\/\/\/\//\/\/\///\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\\/\/\/')
print ('\/\/\/\/\//\/\/\///\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\\/\/\/')
#docfreq = [wordList.count(z) for z in wF]
#dictionary = dict(zip(wF, docfreq))
#count3 = 1
#for j in wF:
    #count3 +=1
#print 'total number of document', count3

for n in range(0,len(keywordList)):
    print (keywordList[n],',', wordfreq[n]/count2)
# term frequency
# total number of times terms occurs in file / total number of word in document

#inverse document frequency
# Out:
# kata :  0 sebanyak  1
# ______________________________________________________________________
# kata :  3660 sebanyak  1
# ______________________________________________________________________
# kata :  tragedikemanusiaankm50the sebanyak  1
# ______________________________________________________________________
# kata :  adaudppnp sebanyak  1
# ______________________________________________________________________
# kata :  juga sebanyak  1
# ______________________________________________________________________
# kata :  syuhada sebanyak  1
# ______________________________________________________________________
# kata :  rojiun sebanyak  1
# ______________________________________________________________________
# kata :  httpstcoqcyvs9knaytangkapanakpaklurah sebanyak  1
# ______________________________________________________________________
# kata :  revenger1924 sebanyak  1
# ______________________________________________________________________
# ...
